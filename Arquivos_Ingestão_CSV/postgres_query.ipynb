# %% [markdown]
# ### Query para criar tabelas no banco de dados PostgreSQL, realizar a ingestão de arquivos CSV e relacioná-las com os schemas

# %%
# %sql
CREATE TABLE IF NOT EXISTS Clientes (
    id SERIAL PRIMARY KEY,
    nome VARCHAR(50) ,
    email VARCHAR(50) UNIQUE,
    cidade VARCHAR(50)
);

CREATE TABLE IF NOT EXISTS itens_pedido (
    id SERIAL PRIMARY KEY,
    pedido_id INT REFERENCES pedido(id),
    produto_id INT REFERENCES produtos(id),
    quantidade INT ,
    preco_unitario NUMERIC(10,2) );

CREATE TABLE IF NOT EXISTS pedido (
    id SERIAL PRIMARY KEY,
    cliente_id INT REFERENCES clientes(id),
    data DATE ,
    valor_total NUMERIC(10,2) );


CREATE TABLE IF NOT EXISTS produtos (
    id SERIAL PRIMARY KEY,
    nome VARCHAR(50),
    categoria VARCHAR(50) DEFAULT 'Sem categoria',
    preco NUMERIC(10,2) DEFAULT '0'
);


SELECT current_database();

-- script para identificar tabela/Schema

SELECT table_schema, table_name
FROM information_schema.tables
WHERE table_type = 'BASE TABLE'
ORDER BY table_schema, table_name;

select * from pedido;
select * from produtos;
select * from itens_pedido;
select * from clientes;

TRUNCATE TABLE pedido, clientes,produtos,itens_pedido;


-- criar um join , para ver todos os dados juntos 

SELECT 
		D.cliente_id ,
		D.data ,
		D.valor_total,
		P.nome,
		P.categoria,
		P.preco ,
		I.quantidade,
		I.preco_unitario,
		C.nome,
		C.email,
		C.cidade
FROM
	pedido as D
FULL JOIN 
	produtos as P 
		ON D.id = P
FULL JOIN 
	itens_pedido as I
FULL JOIN 
	clientes as C
ON
